# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Siranjeevi C\Data Science - Python\Suicide\master.csv')

# %%
#data processing
df.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27820, step=1)

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.fillna('HDI for year', inplace = True)

# %%
df.isnull().sum()
# Out:
# country               0
# year                  0
# sex                   0
# age                   0
# suicides_no           0
# population            0
# suicides/100k pop     0
# country-year          0
# HDI for year          0
#  gdp_for_year ($)     0
# gdp_per_capita ($)    0
# generation            0
# dtype: int64

# %%
plt.rcParams['figure.figsize'] = [50,50]
df.hist(by ='country')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FECEAC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FF727AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FF835898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FC60FC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FCF2EB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FD1580F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FF24B630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FFC1E978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8FFC1E278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880C219E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B880A1AD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880B5C2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880006860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880011DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88001D390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88002C908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880036E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880042438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88004E9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88005AF28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8800674E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880078A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880092FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8800B1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8800D0B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8800F80B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880117630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880136BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880160160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88017F6D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B88019FC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8801C7208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8801E9780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880211CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8802422B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880268828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880291DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8802C3358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8802EA8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880312E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B880342400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88036A978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880395EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8803C54A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8803EEA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880417F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880446550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88046FAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8804A0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8804C75F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8804F1B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880522128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8805496A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880570C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8805A01D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8805C8748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8805F0CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880621278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88064B7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880673D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8806A4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8806CB898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8806F4E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8807243C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88074B940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B880774EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8807A4470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88222D9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882257F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882286518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8822ADA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8822DF048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8823065C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88232EB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88235F0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882388668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8823B0BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8823E2198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88240B710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882431C88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B882463240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88248A7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8824B1D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8824E42E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88250A860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882533DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882565390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88258C908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8825B5E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8825E6438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B88260B9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882634F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8826644E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88268CA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8826B8FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8826E7588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88270FB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8827410B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882768630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882790BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B8827C2160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8827E86D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882812C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882842208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B88286A780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882893CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8828C22B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B8828EA828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882912DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B882943358>]],
#       dtype=object)

# %%
plt.rcParams['figure.figsize'] = [8,8]
plt.bar(df['year'],df['suicides_no'])
# Out:
# <BarContainer object of 27820 artists>

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987  HDI for year      2,156,624,900
# 1               5.19  Albania1987  HDI for year      2,156,624,900
# 2               4.83  Albania1987  HDI for year      2,156,624,900
# 3               4.59  Albania1987  HDI for year      2,156,624,900
# 4               3.28  Albania1987  HDI for year      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
df['country'].value_counts()
# Out:
# Netherlands               382
# Austria                   382
# Mauritius                 382
# Iceland                   382
# Puerto Rico               372
# Malta                     372
# Greece                    372
# Argentina                 372
# Israel                    372
# Italy                     372
# Luxembourg                372
# Spain                     372
# Brazil                    372
# Mexico                    372
# Republic of Korea         372
# Ecuador                   372
# United Kingdom            372
# Singapore                 372
# Colombia                  372
# United States             372
# Belgium                   372
# Japan                     372
# Chile                     372
# Guatemala                 360
# France                    360
# Norway                    360
# Costa Rica                360
# Ireland                   360
# Bulgaria                  360
# Australia                 360
#                          ...
# Belarus                   252
# Estonia                   252
# Latvia                    252
# Switzerland               252
# Slovenia                  252
# South Africa              240
# Serbia                    216
# Seychelles                216
# Jamaica                   204
# Azerbaijan                192
# Philippines               180
# Qatar                     178
# Cyprus                    178
# Aruba                     168
# Kiribati                  132
# Fiji                      132
# Sri Lanka                 132
# Maldives                  120
# Montenegro                120
# Turkey                     84
# Nicaragua                  72
# United Arab Emirates       72
# Oman                       36
# San Marino                 36
# Saint Kitts and Nevis      36
# Bosnia and Herzegovina     24
# Macau                      12
# Cabo Verde                 12
# Dominica                   12
# Mongolia                   10
# Name: country, Length: 101, dtype: int64

# %%
df = df.drop(['country-year','HDI for year'], axis = 1)

# %%
df.isnull().sum()
# Out:
# country               0
# year                  0
# sex                   0
# age                   0
# suicides_no           0
# population            0
# suicides/100k pop     0
#  gdp_for_year ($)     0
# gdp_per_capita ($)    0
# generation            0
# dtype: int64

# %%
df['generation'].value_counts()
# Out:
# Generation X       6408
# Silent             6364
# Millenials         5844
# Boomers            4990
# G.I. Generation    2744
# Generation Z       1470
# Name: generation, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 15-24 years    4642
# 25-34 years    4642
# 75+ years      4642
# 35-54 years    4642
# 55-74 years    4642
# 5-14 years     4610
# Name: age, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2009    1068
# 2001    1056
# 2010    1056
# 2007    1032
# 2011    1032
# 2002    1032
# 2003    1032
# 2000    1032
# 2006    1020
# 2008    1020
# 2005    1008
# 2004    1008
# 1999     996
# 2012     972
# 2013     960
# 1998     948
# 2014     936
# 1995     936
# 1996     924
# 1997     924
# 1994     816
# 1992     780
# 1993     780
# 1990     768
# 1991     768
# 2015     744
# 1987     648
# 1989     624
# 1988     588
# 1986     576
# 1985     576
# 2016     160
# Name: year, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Country'] = encoder.fit_transform(df['country'])
df['Sex'] = encoder.fit_transform(df['sex'])
df['Generation'] = encoder.fit_transform(df['generation'])
df['Age'] = encoder.fit_transform(df['age'])
df['Year'] = encoder.fit_transform(df['year'])
df.head(5)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop  gdp_for_year ($)   gdp_per_capita ($)       generation  \
# 0               6.71      2,156,624,900                 796     Generation X
# 1               5.19      2,156,624,900                 796           Silent
# 2               4.83      2,156,624,900                 796     Generation X
# 3               4.59      2,156,624,900                 796  G.I. Generation
# 4               3.28      2,156,624,900                 796          Boomers
#
#    Country  Sex  Generation  Age  Year
# 0        0    1           2    0     2
# 1        0    1           5    2     2
# 2        0    0           2    0     2
# 3        0    1           1    5     2
# 4        0    1           0    1     2

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', ' gdp_for_year ($) ', 'gdp_per_capita ($)',
#        'generation', 'Country', 'Sex', 'Generation', 'Age', 'Year'],
#       dtype='object')

# %%
df = df.drop(['country', 'year', 'sex', 'age', 'suicides/100k pop', ' gdp_for_year ($) ','generation'] ,  axis = 1)

# %%
df.dtypes
# Out:
# suicides_no           int64
# population            int64
# gdp_per_capita ($)    int64
# Country               int32
# Sex                   int32
# Generation            int32
# Age                   int32
# Year                  int64
# dtype: object

# %%
df.head(5)
# Out:
#    suicides_no  population  gdp_per_capita ($)  Country  Sex  Generation  Age  \
# 0           21      312900                 796        0    1           2    0
# 1           16      308000                 796        0    1           5    2
# 2           14      289700                 796        0    0           2    0
# 3            1       21800                 796        0    1           1    5
# 4            9      274300                 796        0    1           0    1
#
#    Year
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2

# %%
#to set in independent and depentdent variable
x = df.drop(['suicides_no'],axis = 1)
y = df['suicides_no']

# %%
x,y
# Out:
# (       population  gdp_per_capita ($)  Country  Sex  Generation  Age  Year
#  0          312900                 796        0    1           2    0     2
#  1          308000                 796        0    1           5    2     2
#  2          289700                 796        0    0           2    0     2
#  3           21800                 796        0    1           1    5     2
#  4          274300                 796        0    1           0    1     2
#  5           35600                 796        0    0           1    5     2
#  6          278800                 796        0    0           5    2     2
#  7          257200                 796        0    0           0    1     2
#  8          137500                 796        0    1           1    4     2
#  9          311000                 796        0    0           2    3     2
#  10         144600                 796        0    0           1    4     2
#  11         338200                 796        0    1           2    3     2
#  12          36400                 769        0    0           1    5     3
#  13         319200                 769        0    1           2    0     3
#  14          22300                 769        0    1           1    5     3
#  15         314100                 769        0    1           5    2     3
#  16         140200                 769        0    1           1    4     3
#  17         295600                 769        0    0           2    0     3
#  18         147500                 769        0    0           1    4     3
#  19         262400                 769        0    0           0    1     3
#  20         279900                 769        0    1           0    1     3
#  21         284500                 769        0    0           5    2     3
#  22         317200                 769        0    0           2    3     3
#  23         345000                 769        0    1           2    3     3
#  24          22500                 833        0    1           1    5     4
#  25         283600                 833        0    1           0    1     4
#  26         318400                 833        0    1           5    2     4
#  27         142100                 833        0    1           1    4     4
#  28         323500                 833        0    1           2    0     4
#  29         288600                 833        0    0           5    2     4
#  ...           ...                 ...      ...  ...         ...  ...   ...
#  27790     2556673                1964      100    0           4    1    27
#  27791     3474788                1964      100    0           2    2    27
#  27792     2701361                1964      100    1           3    3    27
#  27793     1283060                1964      100    0           0    4    27
#  27794      338557                1964      100    0           5    5    27
#  27795     2578408                1964      100    0           3    3    27
#  27796     3346411                2150      100    1           2    2    28
#  27797     2644648                2150      100    1           4    1    28
#  27798     3039740                2150      100    0           4    0    28
#  27799     3171202                2150      100    1           4    0    28
#  27800     1202790                2150      100    1           0    4    28
#  27801      221002                2150      100    1           5    5    28
#  27802     2647820                2150      100    0           4    1    28
#  27803     3547895                2150      100    0           2    2    28
#  27804      345180                2150      100    0           5    5    28
#  27805     2720938                2150      100    1           3    3    28
#  27806     1356298                2150      100    0           0    4    28
#  27807     2595000                2150      100    0           3    3    28
#  27808     3421300                2309      100    1           2    2    29
#  27809     2739150                2309      100    1           4    1    29
#  27810     2992817                2309      100    0           4    0    29
#  27811     1271111                2309      100    1           0    4    29
#  27812     3126905                2309      100    1           4    0    29
#  27813      224995                2309      100    1           5    5    29
#  27814     2735238                2309      100    0           4    1    29
#  27815     3620833                2309      100    0           2    2    29
#  27816      348465                2309      100    0           5    5    29
#  27817     2762158                2309      100    1           3    3    29
#  27818     2631600                2309      100    0           3    3    29
#  27819     1438935                2309      100    0           0    4    29
#
#  [27820 rows x 7 columns], 0         21
#  1         16
#  2         14
#  3          1
#  4          9
#  5          1
#  6          6
#  7          4
#  8          1
#  9          0
#  10         0
#  11         0
#  12         2
#  13        17
#  14         1
#  15        14
#  16         4
#  17         8
#  18         3
#  19         5
#  20         5
#  21         4
#  22         0
#  23         0
#  24         2
#  25        18
#  26        15
#  27         6
#  28        12
#  29         7
#          ...
#  27790    148
#  27791     89
#  27792     67
#  27793     25
#  27794      4
#  27795     16
#  27796    481
#  27797    328
#  27798    323
#  27799    320
#  27800    119
#  27801     13
#  27802    146
#  27803     99
#  27804      8
#  27805     61
#  27806     21
#  27807     31
#  27808    519
#  27809    318
#  27810    347
#  27811    144
#  27812    347
#  27813     17
#  27814    162
#  27815    107
#  27816      9
#  27817     60
#  27818     44
#  27819     21
#  Name: suicides_no, Length: 27820, dtype: int64)

# %%
#to split train and test data
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 3)

# %%
#creating regression object
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=10)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# Make predictions using the testing set
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
print('R2 SCORE:\n',r2_score(y_pred,y_test))
# Out:
# R2 SCORE:
#  0.9827541969346888

# %%
plt.rcParams['figure.figsize'] = [10,10]
plt.scatter(model.predict(x_train),model.predict( x_train)- y_train, c= 'b', s=40, alpha = 0.5)
plt.scatter(model.predict(x_test), model.predict(x_test)-y_test, c='g', s=40)
plt.title('Residual Plot')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(estimator = model , X = x_train , y= y_train , cv = 10)
print("Cross Validation score : ",accuracy.mean())
print("standard Deviation : ",accuracy.std())
# Out:
# Cross Validation score :  0.9655422427899192
# standard Deviation :  0.023253470726456577
